# %% [markdown]
# # Lesson 8 - Hierarchically Chaining the Agent Calls using a Router Agent

# %% [markdown]
# You will now create a hierarchical workflow using a router agent. Instead of having a fixed linear workflow like in the previous lesson, you will use a third agent (router) in the client-side that will decide when to call each ACP agent.

# %% [markdown]
# ## 8.1. Start Up both ACP Servers

# %% [markdown]
# First make sure the Insurer server is still running:
# - Open the terminal by running the cell below.
# - If the agent is still running from the previous lessons, then you don't need to do anything else.
# - If the agent has stopped running (the lab environment resets after 120 min), then you can run the server again by typing:
#   - `uv run crew_agent_server.py`
#
#
# **Note**: If you see this warning:
# `WARNING: Can not reach server, check if running on http://127.0.0.1:8333 : Request failed after 5 retries`
# you can ignore it. You'll learn later in another lesson about the BeeAI platform, which a registry you can use to manage and discover agents. If the platform is installed, it runs by default on port 8333. The ACP servers are configured to automatically connect to the platform. Since the platform is not installed in this environment, the ACP server will generate a warning.

# %%
from IPython.display import IFrame
import os
url = os.environ.get('DLAI_LOCAL_URL').format(port=8888)
IFrame(f"{url}terminals/1", width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://s172-29-1-109p8888.lab-aws-production.deeplearning.ai/terminals/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Also make sure the Hospital server is still running:
# - Open the terminal by running the cell below.
# - If the agent is still running from the previous lessons, then you don't need to do anything else.
# - If the agent has stopped running (the lab environment resets after 120 min), then you can run the server again by typing:
#   - `uv run smolagents_server.py`

# %%
IFrame(f"{url}terminals/2", width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://s172-29-1-109p8888.lab-aws-production.deeplearning.ai/terminals/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 8.2. Import ACPCallingAgent

# %% [markdown]
# The router agent is already implemented for you as the `ACPCallingAgent`. You are provided with a python file called `fastacp.py` where you can find the definition of the `ACPCallingAgent`.

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>To access the <code>fastacp.py</code> file:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook, 2) click on <em>"Open"</em> and then 3) click on L8.
# </p>

# %%
import asyncio 
import nest_asyncio
from acp_sdk.client import Client
from smolagents import LiteLLMModel
from fastacp import AgentCollection, ACPCallingAgent
from colorama import Fore

# %%
print(ACPCallingAgent.__doc__)
# Out:
#     This agent uses JSON-like ACP agent calls, similarly to how ToolCallingAgent uses tool calls,
#     but directed at remote ACP agents instead of local tools.
#
#     Args:
#         acp_agents (`dict[str, Agent]`): ACP agents that this agent can call.
#         model (`Callable[[list[dict[str, str]]], ChatMessage]`): Model that will generate the agent's actions.
#         prompt_templates ([`Dict[str, str]`], *optional*): Prompt templates.
#         planning_interval (`int`, *optional*): Interval at which the agent will run a planning step.
#         **kwargs: Additional keyword arguments.

# %% [markdown]
# ## 8.3. Run the Hierarchical Workflow

# %%
nest_asyncio.apply()

# %% [markdown]
# **Note**: The `fastacp.py` file does not only contain the definition for the ACPCallingAgent, but it also includes this method: `AgentCollection.from_acp` where the client objects (`insurer` and `hospital`) discover the agents hosted on their corresponding servers by calling the method `.agents()`.

# %%
model = LiteLLMModel(
    model_id="openai/gpt-4"
)

async def run_hospital_workflow() -> None:
    async with Client(base_url="http://localhost:8001") as insurer, Client(base_url="http://localhost:8000") as hospital:
        # agents discovery
        agent_collection = await AgentCollection.from_acp(insurer, hospital)  
        acp_agents = {agent.name: {'agent':agent, 'client':client} for client, agent in agent_collection.agents}
        print(acp_agents) 
        # passing the agents as tools to ACPCallingAgent
        acpagent = ACPCallingAgent(acp_agents=acp_agents, model=model)
        # running the agent with a user query
        result = await acpagent.run("do i need rehabilitation after a shoulder reconstruction and what is the waiting period from my insurance?")
        print(Fore.YELLOW + f"Final result: {result}" + Fore.RESET)

# %%
asyncio.run(run_hospital_workflow())
# Out:
# {'policy_agent': {'agent': Agent(name='policy_agent', description='This is an agent for questions around policy coverage, it uses a RAG pattern to find answers based on policy documentation. Use it to help answer questions on coverage and waiting periods.', metadata=Metadata(annotations=None, documentation=None, license=None, programming_language=None, natural_languages=None, framework=None, capabilities=None, domains=None, tags=None, created_at=None, updated_at=None, author=None, contributors=None, links=None, dependencies=None, recommended_models=None)), 'client': <acp_sdk.client.client.Client object at 0x7fb9479c1a10>}, 'health_agent': {'agent': Agent(name='health_agent', description='This is a CodeAgent which supports the hospital to handle health based questions for patients. Current or prospective patients can use it to find answers about their health and hospital treatments.', metadata=Metadata(annotations=None, documentation=None, license=None, programming_language=None, natural_languages=None, framework=None, capabilities=None, domains=None, tags=None, created_at=None, updated_at=None, author=None, contributors=None, links=None, dependencies=None, recommended_models=None)), 'client': <acp_sdk.client.client.Client object at 0x7fb956137590>}}
# [INFO] Step 1/10
# [DEBUG] Output message of the LLM:
# [DEBUG] ModelResponse(id='chatcmpl-BlrsVURrwOcd4XBwD9oVIy8nar9oE', created=1750748223, model='gpt-4-0613', object='chat.completion', system_fingerprint=None, choices=[Choices(finish_reason='stop', index=0, message=Message(content=None, role='assistant', tool_calls=[ChatCompletionMessageToolCall(function=Function(arguments='{\n  "input": "do i need rehabilitation after a shoulder reconstruction?"\n}', name='health_agent'), id='call_E4PX48BGXXumR938k10S78CS', type='function')], function_call=None, provider_specific_fields={'refusal': None}, annotations=[]))], usage=Usage(completion_tokens=20, prompt_tokens=418, total_tokens=438, completion_tokens_details=CompletionTokensDetailsWrapper(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0, text_tokens=None), prompt_tokens_details=PromptTokensDetailsWrapper(audio_tokens=0, cached_tokens=0, text_tokens=None, image_tokens=None)), service_tier='default')
# [INFO] Calling agent: 'health_agent' with arguments: {
#   "input": "do i need rehabilitation after a shoulder reconstruction?"
# }
# Tool being called with args: ('{\n  "input": "do i need rehabilitation after a shoulder reconstruction?"\n}',) and kwargs: {'sanitize_inputs_outputs': True}
# {
#   "input": "do i need rehabilitation after a shoulder reconstruction?"
# }
# run_id=UUID('9c9b3ba3-5f62-4546-92be-067448062e87') agent_name='health_agent' session_id=UUID('560429fa-3814-459b-a302-1b89edfac069') status=<RunStatus.COMPLETED: 'completed'> await_request=None output=[Message(parts=[MessagePart(name=None, content_type='text/plain', content='Yes, rehabilitation is necessary after a shoulder reconstruction for a successful recovery.', content_encoding='plain', content_url=None)], created_at=datetime.datetime(2025, 6, 25, 19, 23, 34, 33847, tzinfo=TzInfo(UTC)), completed_at=datetime.datetime(2025, 6, 25, 19, 23, 34, 33850, tzinfo=TzInfo(UTC)))] error=None created_at=datetime.datetime(2025, 6, 25, 19, 23, 29, 274492, tzinfo=TzInfo(UTC)) finished_at=datetime.datetime(2025, 6, 25, 19, 23, 34, 34245, tzinfo=TzInfo(UTC))
# [DEBUG] Saved to memory: health_agent_response=Yes, rehabilitation is necessary after a shoulder reconstruction for a successful recovery.
# [INFO] Observations: Yes, rehabilitation is necessary after a shoulder reconstruction for a successful recovery.
# [INFO] Step 2/10
# [DEBUG] Output message of the LLM:
# [DEBUG] ModelResponse(id='chatcmpl-BmQ0Uqqz8ZP6oivf6HTJzXk8lf5B8', created=1750879414, model='gpt-4-0613', object='chat.completion', system_fingerprint=None, choices=[Choices(finish_reason='stop', index=0, message=Message(content=None, role='assistant', tool_calls=[ChatCompletionMessageToolCall(function=Function(arguments='{\n  "input": "what is the waiting period for shoulder reconstruction rehabilitation from my insurance"\n}', name='policy_agent'), id='call_2nufK4M3U80DFrJKAiqtxCbz', type='function')], function_call=None, provider_specific_fields={'refusal': None}, annotations=[]))], usage=Usage(completion_tokens=24, prompt_tokens=462, total_tokens=486, completion_tokens_details=CompletionTokensDetailsWrapper(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0, text_tokens=None), prompt_tokens_details=PromptTokensDetailsWrapper(audio_tokens=0, cached_tokens=0, text_tokens=None, image_tokens=None)), service_tier='default')
# [INFO] Calling agent: 'policy_agent' with arguments: {
#   "input": "what is the waiting period for shoulder reconstruction rehabilitation from my insurance"
# }
# Tool being called with args: ('{\n  "input": "what is the waiting period for shoulder reconstruction rehabilitation from my insurance"\n}',) and kwargs: {'sanitize_inputs_outputs': True}
# {
#   "input": "what is the waiting period for shoulder reconstruction rehabilitation from my insurance"
# }
# run_id=UUID('08a1dd5a-4fe3-471e-9580-91cd2b4b2832') agent_name='policy_agent' session_id=UUID('4dfd4194-08af-464c-bc92-834ff38ecee5') status=<RunStatus.COMPLETED: 'completed'> await_request=None output=[Message(parts=[MessagePart(name=None, content_type='text/plain', content="The waiting period for shoulder reconstruction rehabilitation is 2 months, provided it's not a pre-existing condition. If it's a pre-existing condition, you would have to wait 12 months. Also, you would need a referral from your treating doctor to be eligible.", content_encoding='plain', content_url=None)], created_at=datetime.datetime(2025, 6, 25, 19, 23, 45, 976183, tzinfo=TzInfo(UTC)), completed_at=datetime.datetime(2025, 6, 25, 19, 23, 45, 976187, tzinfo=TzInfo(UTC)))] error=None created_at=datetime.datetime(2025, 6, 25, 19, 23, 35, 949494, tzinfo=TzInfo(UTC)) finished_at=datetime.datetime(2025, 6, 25, 19, 23, 45, 976483, tzinfo=TzInfo(UTC))
# [DEBUG] Saved to memory: policy_agent_response=The waiting period for shoulder reconstruction rehabilitation is 2 months, provided it's not a pre-existing condition. If it's a pre-existing condition, you would have to wait 12 months. Also, you would need a referral from your treating doctor to be eligible.
# [INFO] Observations: The waiting period for shoulder reconstruction rehabilitation is 2 months, provided it's not a pre-existing condition. If it's a pre-existing condition, you would have to wait 12 months. Also, you would need a referral from your treating doctor to be eligible.
# [INFO] Step 3/10
# [DEBUG] Output message of the LLM:
# [DEBUG] ModelResponse(id='chatcmpl-BmQ0gqWMUTh8kA02vPJpeSmzmgIaX', created=1750879426, model='gpt-4-0613', object='chat.completion', system_fingerprint=None, choices=[Choices(finish_reason='stop', index=0, message=Message(content=None, role='assistant', tool_calls=[ChatCompletionMessageToolCall(function=Function(arguments="Yes, rehabilitation is necessary after a shoulder reconstruction for a successful recovery. However, your insurance policy requires a waiting period of 2 months for shoulder reconstruction rehabilitation, provided it's not a pre-existing condition. If it is a pre-existing condition, you would have to wait 12 months. Additionally, you would need a referral from your treating doctor for the rehabilitation to be eligible.", name='final_answer'), id='call_mar86tMfrj9PHnMlHGRmFsny', type='function')], function_call=None, provider_specific_fields={'refusal': None}, annotations=[]))], usage=Usage(completion_tokens=80, prompt_tokens=607, total_tokens=687, completion_tokens_details=CompletionTokensDetailsWrapper(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0, text_tokens=None), prompt_tokens_details=PromptTokensDetailsWrapper(audio_tokens=0, cached_tokens=0, text_tokens=None, image_tokens=None)), service_tier='default')
# [INFO] Calling agent: 'final_answer' with arguments: Yes, rehabilitation is necessary after a shoulder reconstruction for a successful recovery. However, your insurance policy requires a waiting period of 2 months for shoulder reconstruction rehabilitation, provided it's not a pre-existing condition. If it is a pre-existing condition, you would have to wait 12 months. Additionally, you would need a referral from your treating doctor for the rehabilitation to be eligible.
# [INFO] Final answer: Yes, rehabilitation is necessary after a shoulder reconstruction for a successful recovery. However, your insurance policy requires a waiting period of 2 months for shoulder reconstruction rehabilitation, provided it's not a pre-existing condition. If it is a pre-existing condition, you would have to wait 12 months. Additionally, you would need a referral from your treating doctor for the rehabilitation to be eligible.
# Final result: Yes, rehabilitation is necessary after a shoulder reconstruction for a successful recovery. However, your insurance policy requires a waiting period of 2 months for shoulder reconstruction rehabilitation, provided it's not a pre-existing condition. If it is a pre-existing condition, you would have to wait 12 months. Additionally, you would need a referral from your treating doctor for the rehabilitation to be eligible.

# %% [markdown]
# **Optional Reading:** Here's how the hierarchical flow works using the provided file `fastacp.py`:
#
# 1. The agents hosted on each server are first discovered by their corresponding client objects and then converted to tools for the router agent (ACPCallingAgent):
#
#   <img src="hr_1.png" width="650">
#
# 2. When the router agent receives a user query, it breaks downs the query into smaller steps where each step can be executed by the specialized agent. For a given step, the router agent uses the client of the specialized agent to send the request to it:
#
#   <img src="hr_2.png" width="650">

# %% [markdown]
# ## 8.4. Resources

# %% [markdown]
# - [Compose Agents](https://agentcommunicationprotocol.dev/how-to/compose-agents)
# - [Chained Agents as a Python file](https://github.com/nicknochnack/ACPWalkthrough/blob/main/5.%20Chained%20Agents.py)

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>To access the <code>my_acp_project</code> folder:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>.

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
# <p> ⬇ &nbsp; <b>Download Notebooks:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Download as"</em> and select <em>"Notebook (.ipynb)"</em>.</p>
# </div>
