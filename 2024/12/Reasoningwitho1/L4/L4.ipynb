# %% [markdown]
# # Lesson 4: Coding with o1

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
# <p> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>.
#
# <p> ⬇ &nbsp; <b>Download Notebooks:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Download as"</em> and select <em>"Notebook (.ipynb)"</em>.</p>
#
# <p> 📒 &nbsp; For more help, please see the <em>"Appendix – Tips, Help, and Download"</em> Lesson.</p>
#
# </div>

# %% [markdown]
# <p style="background-color:#f7fff8; padding:15px; border-width:3px; border-color:#e0f0e0; border-style:solid; border-radius:6px"> 🚨
# &nbsp; <b>Different Run Results:</b> The output generated by AI models can vary with each execution due to their dynamic, probabilistic nature. Don't be surprised if your results differ from those shown in the video.</p>

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Import OpenAI key
from helper import get_openai_api_key
openai_api_key = get_openai_api_key()

# %%
from IPython.display import display, Image, Markdown
from openai import OpenAI

client = OpenAI(api_key=openai_api_key)
GPT_MODEL = 'gpt-4o-mini'
O1_MODEL = 'o1-mini'

# %% [markdown]
# ## Create

# %%
def get_chat_completion(model, prompt):
    """
    Calls the OpenAI API to get a chat completion.

    :param model: The model to use for the completion.
    :param prompt: The prompt to send to the model.
    :return: The completion response from the model.
    """
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
    )
    return response.choices[0].message.content

# %%
react_demo_prompt = """Create an elegant, delightful React component for an Interview Feedback Form where:

1. The interviewer rates candidates across multiple dimensions using rubrics
2. Each rating must include specific evidence/examples
3. The final recommendation should auto-calculate based on a weighted scoring system
4. The UI should guide interviewers to give specific, behavioral feedback

The goal is to enforce structured, objective feedback gathering. A smart model should:
- Create a thoughtful rubric structure
- Add helpful prompts/placeholders
- Build in intelligent validation

Make sure to
 - Call the element FeedbackForm
 - Start the code with "use client"

Respond with the code only! Nothing else!"""

# %%
gpt_code = get_chat_completion(GPT_MODEL, react_demo_prompt)

# %%
print(gpt_code)
# Out:
# ```javascript
# "use client";
#
# import React, { useState } from 'react';
#
# const FeedbackForm = () => {
#   const [ratings, setRatings] = useState({
#     communication: { score: 0, evidence: "" },
#     problemSolving: { score: 0, evidence: "" },
#     teamwork: { score: 0, evidence: "" },
#     adaptability: { score: 0, evidence: "" },
#   });
#
#   const weightedScores = {
#     communication: 0.25,
#     problemSolving: 0.35,
#     teamwork: 0.2,
#     adaptability: 0.2,
#   };
#
#   const handleRatingChange = (dimension, score) => {
#     setRatings(prev => ({
#       ...prev,
#       [dimension]: { ...prev[dimension], score },
#     }));
#   };
#
#   const handleEvidenceChange = (dimension, evidence) => {
#     setRatings(prev => ({
#       ...prev,
#       [dimension]: { ...prev[dimension], evidence },
#     }));
#   };
#
#   const calculateRecommendation = () => {
#     let totalScore = 0;
#     for (const dimension in ratings) {
#       totalScore += ratings[dimension].score * weightedScores[dimension];
#     }
#     return totalScore >= 3 ? "Recommend" : "Do Not Recommend";
#   };
#
#   const handleSubmit = (e) => {
#     e.preventDefault();
#     const recommendation = calculateRecommendation();
#     alert(`Final Recommendation: ${recommendation}`);
#   };
#
#   return (
#     <form onSubmit={handleSubmit} style={{ padding: '20px', border: '1px solid #ccc', borderRadius: '5px' }}>
#       <h2>Interview Feedback Form</h2>
#       {Object.keys(ratings).map(dimension => (
#         <div key={dimension} style={{ margin: '20px 0' }}>
#           <label>{dimension.charAt(0).toUpperCase() + dimension.slice(1)} Rating (0-5): </label>
#           <input
#             type="number"
#             min="0"
#             max="5"
#             value={ratings[dimension].score}
#             onChange={(e) => handleRatingChange(dimension, parseInt(e.target.value))}
#             required
#             placeholder={`Rate ${dimension} from 0 to 5`}
#           />
#           <br />
#           <textarea
#             value={ratings[dimension].evidence}
#             onChange={(e) => handleEvidenceChange(dimension, e.target.value)}
#             placeholder={`Provide specific examples for ${dimension}`}
#             required
#             style={{ width: '100%', height: '80px', marginTop: '10px' }}
#           />
#         </div>
#       ))}
#       <button type="submit">Submit Feedback</button>
#     </form>
#   );
# };
#
# export default FeedbackForm;
# ```

# %%
display(Image('gpt4_app_image.png'))

# %%
o1_code = get_chat_completion(O1_MODEL, react_demo_prompt)

# %%
print(o1_code)
# Out:
# ```javascript
# 'use client'
#
# import React, { useState } from 'react';
#
# const FeedbackForm = () => {
#   const rubrics = [
#     { id: 'communication', name: 'Communication', weight: 0.3 },
#     { id: 'technical_skills', name: 'Technical Skills', weight: 0.4 },
#     { id: 'problem_solving', name: 'Problem Solving', weight: 0.3 },
#   ];
#
#   const initialState = rubrics.reduce((acc, rubric) => {
#     acc[rubric.id] = { rating: '', evidence: '' };
#     return acc;
#   }, {});
#
#   const [formData, setFormData] = useState(initialState);
#   const [errors, setErrors] = useState({});
#   const [totalScore, setTotalScore] = useState(null);
#
#   const handleChange = (id, field, value) => {
#     setFormData({
#       ...formData,
#       [id]: {
#         ...formData[id],
#         [field]: value,
#       },
#     });
#     setErrors({
#       ...errors,
#       [`${id}_${field}`]: '',
#     });
#   };
#
#   const validate = () => {
#     let valid = true;
#     let newErrors = {};
#
#     rubrics.forEach(rubric => {
#       if (!formData[rubric.id].rating) {
#         valid = false;
#         newErrors[`${rubric.id}_rating`] = 'Rating is required.';
#       }
#       if (!formData[rubric.id].evidence.trim()) {
#         valid = false;
#         newErrors[`${rubric.id}_evidence`] = 'Evidence is required.';
#       } else if (formData[rubric.id].evidence.trim().length < 20) {
#         valid = false;
#         newErrors[`${rubric.id}_evidence`] = 'Please provide at least 20 characters of evidence.';
#       }
#     });
#
#     setErrors(newErrors);
#     return valid;
#   };
#
#   const calculateScore = () => {
#     let score = 0;
#     rubrics.forEach(rubric => {
#       score += Number(formData[rubric.id].rating) * rubric.weight;
#     });
#     setTotalScore(score.toFixed(2));
#   };
#
#   const handleSubmit = (e) => {
#     e.preventDefault();
#     if (validate()) {
#       calculateScore();
#     }
#   };
#
#   const recommendation = () => {
#     if (totalScore >= 4.5) return 'Highly Recommend';
#     if (totalScore >= 3.5) return 'Recommend';
#     if (totalScore >= 2.5) return 'Neutral';
#     return 'Do Not Recommend';
#   };
#
#   return (
#     <div style={styles.container}>
#       <h2 style={styles.header}>Interview Feedback Form</h2>
#       <form onSubmit={handleSubmit} style={styles.form}>
#         {rubrics.map(rubric => (
#           <div key={rubric.id} style={styles.section}>
#             <h3>{rubric.name} <span style={styles.weight}>({rubric.weight * 100}%)</span></h3>
#             <label style={styles.label}>
#               Rating:
#               <select
#                 value={formData[rubric.id].rating}
#                 onChange={(e) => handleChange(rubric.id, 'rating', e.target.value)}
#                 style={styles.select}
#               >
#                 <option value="">Select rating</option>
#                 {[1,2,3,4,5].map(num => (
#                   <option key={num} value={num}>{num}</option>
#                 ))}
#               </select>
#             </label>
#             {errors[`${rubric.id}_rating`] && <span style={styles.error}>{errors[`${rubric.id}_rating`]}</span>}
#             <label style={styles.label}>
#               Evidence / Examples:
#               <textarea
#                 value={formData[rubric.id].evidence}
#                 onChange={(e) => handleChange(rubric.id, 'evidence', e.target.value)}
#                 placeholder="Provide specific examples related to this area..."
#                 style={styles.textarea}
#               />
#             </label>
#             {errors[`${rubric.id}_evidence`] && <span style={styles.error}>{errors[`${rubric.id}_evidence`]}</span>}
#           </div>
#         ))}
#         <button type="submit" style={styles.button}>Submit Feedback</button>
#       </form>
#       {totalScore && (
#         <div style={styles.result}>
#           <h3>Final Recommendation: {recommendation()}</h3>
#           <p>Total Score: {totalScore} / 5</p>
#         </div>
#       )}
#     </div>
#   );
# };
#
# const styles = {
#   container: {
#     maxWidth: '600px',
#     margin: '30px auto',
#     padding: '20px',
#     fontFamily: 'Arial, sans-serif',
#     backgroundColor: '#f9f9f9',
#     borderRadius: '8px',
#     boxShadow: '0 2px 8px rgba(0,0,0,0.1)',
#   },
#   header: {
#     textAlign: 'center',
#     color: '#333',
#   },
#   form: {
#     display: 'flex',
#     flexDirection: 'column',
#   },
#   section: {
#     marginBottom: '20px',
#     padding: '15px',
#     backgroundColor: '#fff',
#     borderRadius: '6px',
#     boxShadow: '0 1px 4px rgba(0,0,0,0.1)',
#   },
#   label: {
#     display: 'block',
#     marginBottom: '10px',
#     color: '#555',
#   },
#   select: {
#     width: '100%',
#     padding: '8px',
#     marginTop: '5px',
#     borderRadius: '4px',
#     border: '1px solid #ccc',
#   },
#   textarea: {
#     width: '100%',
#     height: '60px',
#     padding: '8px',
#     marginTop: '5px',
#     borderRadius: '4px',
#     border: '1px solid #ccc',
#     resize: 'vertical',
#   },
#   button: {
#     padding: '10px 15px',
#     backgroundColor: '#007BFF',
#     color: '#fff',
#     border: 'none',
#     borderRadius: '4px',
#     cursor: 'pointer',
#     alignSelf: 'center',
#     fontSize: '16px',
#   },
#   error: {
#     color: 'red',
#     fontSize: '12px',
#   },
#   result: {
#     marginTop: '30px',
#     padding: '20px',
#     backgroundColor: '#e6ffe6',
#     borderRadius: '6px',
#     textAlign: 'center',
#   },
#   weight: {
#     fontWeight: 'normal',
#     fontSize: '14px',
#     color: '#777',
#   },
# };
#
# export default FeedbackForm;
# ```

# %%
display(Image('o1_app_image.png'))

# %% [markdown]
# ### Render the generated code yourself!
# There are two ways to try rendering this code yourself. The first is the easiest &#x1F642;
# > Go to this [link](https://onecompiler.com/react), cut the code from the notebook and paste it into the editor.
#
#  The 2nd is more complex:
# > Download a zip file that contains a react app and follow the instructions in the README. This file can be found by 1) Click on the "File" option on the top menu of the notebook and then 2) click on "Open". This will bring up a file view. 3) Click on the box next to the file "app.zip" 4) Click "Download".

# %% [markdown]
# ## Edit
#
# The included code has some clear issues, such as multiple nested loops and a lack of error handling, and also is not very readable. Let's feed the code to both models, and see how they clean it up.

# %%
# Pre-generated code snippet with issues that need to be resolved.
code_snippet = """
def process_orders(orders_list, settings={}, debug=False, notify_customer=True):
    results = []
    errors = []
    notifications = []
    # Process all orders
    for i in range(0, len(orders_list)):
        # Get order
        order = orders_list[i]
        try:
            # Validate order has required fields
            if 'id' in order and 'items' in order and 'customer' in order:
                # Check customer info
                if 'email' in order['customer'] and 'name' in order['customer']:
                    # Validate items
                    items_valid = True
                    total = 0
                    # Check each item
                    for item in order['items']:
                        if not ('product_id' in item and 'quantity' in item):
                            items_valid = False
                            errors.append(f"Invalid item in order {order['id']}")
                            if debug == True:
                                print(f"Debug: Invalid item found in order {order['id']}")
                        else:
                            # Calculate total
                            if 'price' in item:
                                total = total + (item['quantity'] * item['price'])
                            else:
                                items_valid = False
                                errors.append(f"Missing price in order {order['id']}")
                    # Process if items valid
                    if items_valid == True:
                        # Apply any discounts from settings
                        if settings != {} and 'discount' in settings:
                            total = total * (1 - settings['discount'])
                        # Create processed order
                        processed = {
                            'order_id': order['id'],
                            'customer_name': order['customer']['name'],
                            'customer_email': order['customer']['email'],
                            'total': total,
                            'items_count': len(order['items'])
                        }
                        results.append(processed)
                        # Send notification
                        if notify_customer == True:
                            try:
                                # Create notification
                                notification = {
                                    'to': order['customer']['email'],
                                    'subject': 'Order Processed',
                                    'total': total
                                }
                                notifications.append(notification)
                                if debug == True:
                                    print(f"Debug: Notification queued for order {order['id']}")
                            except Exception as e:
                                errors.append(f"Notification failed for order {order['id']}")
                else:
                    errors.append(f"Invalid customer data in order {order['id']}")
            else:
                errors.append(f"Missing required fields in order {order['id']}")
        except Exception as e:
            # Add general error
            errors.append(f"Error processing order {order['id']}: {str(e)}")
            if debug == True:
                print(f"Debug: Error processing order {order['id']}: {str(e)}")

    # Print debug summary
    if debug == True:
        print(f"Debug: Processed {len(results)} orders with {len(errors)} errors")
        print(f"Debug: Queued {len(notifications)} notifications")

    return {
        "processed_orders": results,
        "errors": errors,
        "notifications": notifications
    }
"""

# %%
prompt = f"""I have some code that I'd like you to clean up and improve. Return only the updated code that fixes the issues: {code_snippet}"""
gpt_code = get_chat_completion(GPT_MODEL, prompt)
print(gpt_code)
# Out:
# ```python
# def process_orders(orders_list, settings=None, debug=False, notify_customer=True):
#     if settings is None:
#         settings = {}
#
#     results = []
#     errors = []
#     notifications = []
#
#     # Process all orders
#     for order in orders_list:
#         try:
#             # Validate order has required fields
#             if all(key in order for key in ('id', 'items', 'customer')) and \
#                all(key in order['customer'] for key in ('email', 'name')):
#
#                 items_valid = True
#                 total = 0
#
#                 # Check each item
#                 for item in order['items']:
#                     if not all(key in item for key in ('product_id', 'quantity')):
#                         items_valid = False
#                         errors.append(f"Invalid item in order {order['id']}")
#                         if debug:
#                             print(f"Debug: Invalid item found in order {order['id']}")
#                     else:
#                         # Calculate total
#                         if 'price' in item:
#                             total += item['quantity'] * item['price']
#                         else:
#                             items_valid = False
#                             errors.append(f"Missing price in order {order['id']}")
#
#                 # Process if items valid
#                 if items_valid:
#                     # Apply any discounts from settings
#                     total *= (1 - settings.get('discount', 0))
#
#                     # Create processed order
#                     processed = {
#                         'order_id': order['id'],
#                         'customer_name': order['customer']['name'],
#                         'customer_email': order['customer']['email'],
#                         'total': total,
#                         'items_count': len(order['items'])
#                     }
#                     results.append(processed)
#
#                     # Send notification
#                     if notify_customer:
#                         notification = {
#                             'to': order['customer']['email'],
#                             'subject': 'Order Processed',
#                             'total': total
#                         }
#                         notifications.append(notification)
#                         if debug:
#                             print(f"Debug: Notification queued for order {order['id']}")
#             else:
#                 errors.append(f"Invalid customer data or missing required fields in order {order['id']}")
#
#         except Exception as e:
#             errors.append(f"Error processing order {order['id']}: {str(e)}")
#             if debug:
#                 print(f"Debug: Error processing order {order['id']}: {str(e)}")
#
#     # Print debug summary
#     if debug:
#         print(f"Debug: Processed {len(results)} orders with {len(errors)} errors")
#         print(f"Debug: Queued {len(notifications)} notifications")
#
#     return {
#         "processed_orders": results,
#         "errors": errors,
#         "notifications": notifications
#     }
# ```

# %%
o1_code = get_chat_completion(O1_MODEL, prompt)
print(o1_code)
# Out:
# ```python
# def process_orders(orders_list, settings=None, debug=False, notify_customer=True):
#     results = []
#     errors = []
#     notifications = []
#
#     if settings is None:
#         settings = {}
#
#     # Process all orders
#     for order in orders_list:
#         order_id = order.get('id', 'unknown')
#         try:
#             # Validate order has required fields
#             if all(key in order for key in ('id', 'items', 'customer')):
#                 customer = order['customer']
#                 # Check customer info
#                 if all(key in customer for key in ('email', 'name')):
#                     items_valid = True
#                     total = 0
#                     # Check each item
#                     for item in order['items']:
#                         if not all(k in item for k in ('product_id', 'quantity')):
#                             items_valid = False
#                             errors.append(f"Invalid item in order {order_id}")
#                             if debug:
#                                 print(f"Debug: Invalid item found in order {order_id}")
#                         else:
#                             price = item.get('price')
#                             if price is not None:
#                                 total += item['quantity'] * price
#                             else:
#                                 items_valid = False
#                                 errors.append(f"Missing price in order {order_id}")
#                     # Process if items valid
#                     if items_valid:
#                         discount = settings.get('discount', 0)
#                         if discount:
#                             total *= (1 - discount)
#                         processed = {
#                             'order_id': order_id,
#                             'customer_name': customer['name'],
#                             'customer_email': customer['email'],
#                             'total': total,
#                             'items_count': len(order['items'])
#                         }
#                         results.append(processed)
#                         # Send notification
#                         if notify_customer:
#                             notification = {
#                                 'to': customer['email'],
#                                 'subject': 'Order Processed',
#                                 'total': total
#                             }
#                             notifications.append(notification)
#                             if debug:
#                                 print(f"Debug: Notification queued for order {order_id}")
#                 else:
#                     errors.append(f"Invalid customer data in order {order_id}")
#             else:
#                 errors.append(f"Missing required fields in order {order_id}")
#         except Exception as e:
#             errors.append(f"Error processing order {order_id}: {str(e)}")
#             if debug:
#                 print(f"Debug: Error processing order {order_id}: {str(e)}")
#
#     # Print debug summary
#     if debug:
#         print(f"Debug: Processed {len(results)} orders with {len(errors)} errors")
#         print(f"Debug: Queued {len(notifications)} notifications")
#
#     return {
#         "processed_orders": results,
#         "errors": errors,
#         "notifications": notifications
#     }
# ```

# %%
result = get_chat_completion(O1_MODEL,f"which code is better and why? Option 1: {gpt_code}... or Option 2: {o1_code}")
display(Markdown(result))
# Out:
# Both **Option 1** and **Option 2** aim to process a list of orders by validating their structure, calculating totals, applying discounts, and preparing notifications. While both functions are functionally similar, **Option 2** offers several improvements in terms of code robustness, readability, and maintainability. Here's a detailed comparison highlighting why **Option 2** is the better choice:
#
# ### 1. **Robust Handling of Missing `order_id`**
# - **Option 1** directly accesses `order['id']` when generating error messages. If an order lacks the `'id'` key and isn't properly validated beforehand, this could raise a `KeyError`.
# - **Option 2** uses `order.get('id', 'unknown')` to safely retrieve the `order_id`, ensuring that even if the `'id'` is missing, the code won't crash and will instead use a default value (`'unknown'`). This makes error handling more graceful and reliable.
#
# ### 2. **Efficient Access to Nested Data**
# - **Option 2** assigns `customer = order['customer']` early in the processing. This reduces repetitive dictionary lookups (`order['customer']['email']` and `order['customer']['name']`) later in the code, enhancing both readability and performance.
#
# ### 3. **Cleaner Retrieval of Item Prices**
# - **Option 1** checks for the presence of `'price'` using `'price' in item` before accessing it.
# - **Option 2** uses `item.get('price')`, which not only checks for the existence of the `'price'` key but also retrieves its value in one step. This approach simplifies the code and reduces the risk of `KeyError`.
#
# ### 4. **Consistent and Clear Error Messages**
# - **Option 2** provides more specific error messages, such as `"Invalid customer data in order {order_id}"` and `"Missing required fields in order {order_id}"`. This clarity aids in debugging and monitoring.
# - By having a consistent way of referencing `order_id`, especially when it's set to `'unknown'`, **Option 2** ensures that all error messages are uniformly structured.
#
# ### 5. **Conditional Application of Discounts**
# - Both options apply discounts, but **Option 2** checks if a discount exists before applying it (`if discount:`). While **Option 1** always multiplies by `(1 - settings.get('discount', 0))`, the difference is minimal since multiplying by 1 (when discount is 0) has no effect. However, the conditional check in **Option 2** makes the intention clearer.
#
# ### 6. **Overall Readability and Maintainability**
# - **Option 2** structures the code in a more organized manner, making it easier to follow the flow of logic. Variables are assigned meaningful names, and steps are logically separated, enhancing the overall readability.
# - By minimizing repetitive code and handling potential edge cases more gracefully, **Option 2** is easier to maintain and extend in the future.
#
# ### Conclusion
#
# While both options perform the core functionality effectively, **Option 2** introduces enhancements that make the code safer, clearer, and more maintainable. These improvements are crucial, especially in real-world applications where data can be unpredictable, and robust error handling is essential.
#
# ---
#
# **Recommendation:**
# Choose **Option 2** for its superior handling of potential edge cases, clearer structure, and enhanced readability.
#
# ---
#
# ### Option 2 for Reference:
#
# ```python
# def process_orders(orders_list, settings=None, debug=False, notify_customer=True):
#     results = []
#     errors = []
#     notifications = []
#
#     if settings is None:
#         settings = {}
#
#     # Process all orders
#     for order in orders_list:
#         order_id = order.get('id', 'unknown')
#         try:
#             # Validate order has required fields
#             if all(key in order for key in ('id', 'items', 'customer')):
#                 customer = order['customer']
#                 # Check customer info
#                 if all(key in customer for key in ('email', 'name')):
#                     items_valid = True
#                     total = 0
#                     # Check each item
#                     for item in order['items']:
#                         if not all(k in item for k in ('product_id', 'quantity')):
#                             items_valid = False
#                             errors.append(f"Invalid item in order {order_id}")
#                             if debug:
#                                 print(f"Debug: Invalid item found in order {order_id}")
#                         else:
#                             price = item.get('price')
#                             if price is not None:
#                                 total += item['quantity'] * price
#                             else:
#                                 items_valid = False
#                                 errors.append(f"Missing price in order {order_id}")
#                     # Process if items valid
#                     if items_valid:
#                         discount = settings.get('discount', 0)
#                         if discount:
#                             total *= (1 - discount)
#                         processed = {
#                             'order_id': order_id,
#                             'customer_name': customer['name'],
#                             'customer_email': customer['email'],
#                             'total': total,
#                             'items_count': len(order['items'])
#                         }
#                         results.append(processed)
#                         # Send notification
#                         if notify_customer:
#                             notification = {
#                                 'to': customer['email'],
#                                 'subject': 'Order Processed',
#                                 'total': total
#                             }
#                             notifications.append(notification)
#                             if debug:
#                                 print(f"Debug: Notification queued for order {order_id}")
#                 else:
#                     errors.append(f"Invalid customer data in order {order_id}")
#             else:
#                 errors.append(f"Missing required fields in order {order_id}")
#         except Exception as e:
#             errors.append(f"Error processing order {order_id}: {str(e)}")
#             if debug:
#                 print(f"Debug: Error processing order {order_id}: {str(e)}")
#
#     # Print debug summary
#     if debug:
#         print(f"Debug: Processed {len(results)} orders with {len(errors)} errors")
#         print(f"Debug: Queued {len(notifications)} notifications")
#
#     return {
#         "processed_orders": results,
#         "errors": errors,
#         "notifications": notifications
#     }
# ```
